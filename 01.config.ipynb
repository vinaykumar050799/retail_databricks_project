# %%
class Config():
    def __init__(self):
        self.checkpoint_zone = spark.sql("DESCRIBE EXTERNAL LOCATION checkpoints").select("url").collect()[0][0] + "/retail/"
        self.data_zone = spark.sql("DESCRIBE EXTERNAL LOCATION retail_data_zone").select("url").collect()[0][0]
        self.bronze_path = spark.sql("DESCRIBE EXTERNAL LOCATION retail-managed").select("url").collect()[0][0] +"/bronze"
        self.silver_path = spark.sql("DESCRIBE EXTERNAL LOCATION retail-managed").select("url").collect()[0][0] +"/silver"
        self.gold_path = spark.sql("DESCRIBE EXTERNAL LOCATION retail-managed").select("url").collect()[0][0] +"/gold"

# %%
# display(spark.sql("DESCRIBE EXTERNAL LOCATION retail-managed").select("url").collect()[0][0] + "/retail/")
